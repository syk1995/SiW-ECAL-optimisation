# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
#number of hits

#values from conventional calculation -> starting from energy values and then x-projection
sum_hits_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_mean_test.txt', header=0)
sum_hits_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_test.txt', header=0)
sum_hits_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_test.txt', header=0)
sum_hits_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss2s_test.txt', header=0)
sum_hits_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms68_test.txt', header=0)
sum_hits_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms90_test.txt', header=0)
sum_hits_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_median_test.txt', header=0)
sum_hits_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gamma_test.txt', header=0)


sum_hits_nhits_xproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_xproj.txt')
sum_hits_nhits_yproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_yproj.txt')
sum_hits_nhits_every_bin_xproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_every_bin_mean_xproj.txt')
sum_hits_nhits_every_bin_yproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_every_bin_mean_yproj.txt')


sum_hits_energy_xproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_xproj.txt')
sum_hits_energy_yproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_yproj.txt')
sum_hits_energy_every_bin_xproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_every_bin_mean_xproj.txt')
sum_hits_energy_every_bin_yproj_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_every_bin_mean_yproj.txt')

# %%
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_nhits_xproj_mean['energy'][1:]), sum_hits_nhits_xproj_mean['mean'][1:]/sum_hits_nhits_xproj_mean['energy'][1:], yerr = sum_hits_nhits_xproj_mean['sigma'][1:]/(sum_hits_nhits_xproj_mean['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'nhits_xproj_mean')
plt.errorbar(np.sqrt(sum_hits_nhits_yproj_mean['energy'][1:]), sum_hits_nhits_yproj_mean['mean'][1:]/sum_hits_nhits_yproj_mean['energy'][1:], yerr = sum_hits_nhits_yproj_mean['sigma'][1:]/(np.sqrt(1090) * sum_hits_nhits_yproj_mean['energy'][1:]) ,fmt='-o', label = 'nhits_yproj_mean')
plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_xproj_mean['energy'][1:]), sum_hits_nhits_every_bin_xproj_mean['mean'][1:]/sum_hits_nhits_every_bin_xproj_mean['energy'][1:], yerr = sum_hits_nhits_every_bin_xproj_mean['sigma'][1:]/(sum_hits_nhits_every_bin_xproj_mean['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'nhits_every_bin_xproj_mean')
plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_yproj_mean['energy'][1:]), sum_hits_nhits_every_bin_yproj_mean['mean'][1:]/sum_hits_nhits_every_bin_yproj_mean['energy'][1:], yerr = sum_hits_nhits_every_bin_yproj_mean['sigma'][1:]/(np.sqrt(1990) * sum_hits_nhits_every_bin_yproj_mean['energy'][1:]) ,fmt='-o', label = 'nhits_every_bin_yproj_mean')
plt.title('Linearity Plot for Starting from Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.8)
#plt.ylim(0.99, 1.01)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_nhits_cont.png')

# %%
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_hits_nhits_xproj_mean['energy'][1:]), sum_hits_nhits_xproj_mean['mean'][1:]/sum_hits_nhits_xproj_mean['energy'][1:], yerr = sum_hits_nhits_xproj_mean['sigma'][1:]/(sum_hits_nhits_xproj_mean['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'nhits_xproj_mean')
#plt.errorbar(np.sqrt(sum_hits_nhits_yproj_mean['energy'][1:]), sum_hits_nhits_yproj_mean['mean'][1:]/sum_hits_nhits_yproj_mean['energy'][1:], yerr = sum_hits_nhits_yproj_mean['sigma'][1:]/(np.sqrt(1090) * sum_hits_nhits_yproj_mean['energy'][1:]) ,fmt='-o', label = 'nhits_yproj_mean')
#plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_xproj_mean['energy'][1:]), sum_hits_nhits_every_bin_xproj_mean['mean'][1:]/sum_hits_nhits_every_bin_xproj_mean['energy'][1:], yerr = sum_hits_nhits_every_bin_xproj_mean['sigma'][1:]/(sum_hits_nhits_every_bin_xproj_mean['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'nhits_every_bin_xproj_mean')
plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_yproj_mean['energy'][1:]), sum_hits_nhits_every_bin_yproj_mean['mean'][1:]/sum_hits_nhits_every_bin_yproj_mean['energy'][1:], yerr = sum_hits_nhits_every_bin_yproj_mean['sigma'][1:]/(np.sqrt(1990) * sum_hits_nhits_every_bin_yproj_mean['energy'][1:]) ,fmt='-o', label = 'nhits_every_bin_yproj_mean')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.8)
#plt.ylim(0.75, 1.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_corrected.png')
# Out:
# (0.0, 3.8)

# %%
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_energy_xproj_mean['energy'][1:]), sum_hits_energy_xproj_mean['mean'][1:]/sum_hits_energy_xproj_mean['energy'][1:], yerr = sum_hits_energy_xproj_mean['sigma'][1:]/(sum_hits_energy_xproj_mean['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'energy_xproj_mean')
plt.errorbar(np.sqrt(sum_hits_energy_yproj_mean['energy'][1:]), sum_hits_energy_yproj_mean['mean'][1:]/sum_hits_energy_yproj_mean['energy'][1:], yerr = sum_hits_energy_yproj_mean['sigma'][1:]/(np.sqrt(1090) * sum_hits_energy_yproj_mean['energy'][1:]) ,fmt='-o', label = 'energy_yproj_mean')
plt.errorbar(np.sqrt(sum_hits_energy_every_bin_xproj_mean['energy'][1:]), sum_hits_energy_every_bin_xproj_mean['mean'][1:]/sum_hits_energy_every_bin_xproj_mean['energy'][1:], yerr = sum_hits_energy_every_bin_xproj_mean['sigma'][1:]/(sum_hits_energy_every_bin_xproj_mean['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'energy_every_bin_xproj_mean')
plt.errorbar(np.sqrt(sum_hits_energy_every_bin_yproj_mean['energy'][1:]), sum_hits_energy_every_bin_yproj_mean['mean'][1:]/sum_hits_energy_every_bin_yproj_mean['energy'][1:], yerr = sum_hits_energy_every_bin_yproj_mean['sigma'][1:]/(np.sqrt(1990) * sum_hits_energy_every_bin_yproj_mean['energy'][1:]) ,fmt='-o', label = 'energy_every_bin_yproj_mean')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.56)
#plt.ylim(0.99, 1.01)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_energy_cont.png')

# %%
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_hits_energy_xproj_mean['energy'][1:]), sum_hits_energy_xproj_mean['mean'][1:]/sum_hits_energy_xproj_mean['energy'][1:], yerr = sum_hits_energy_xproj_mean['sigma'][1:]/(sum_hits_energy_xproj_mean['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'energy_xproj_mean')
#plt.errorbar(np.sqrt(sum_hits_energy_yproj_mean['energy'][1:]), sum_hits_energy_yproj_mean['mean'][1:]/sum_hits_energy_yproj_mean['energy'][1:], yerr = sum_hits_energy_yproj_mean['sigma'][1:]/(np.sqrt(1090) * sum_hits_energy_yproj_mean['energy'][1:]) ,fmt='-o', label = 'energy_yproj_mean')
plt.errorbar(np.sqrt(sum_hits_energy_every_bin_xproj_mean['energy'][1:]), sum_hits_energy_every_bin_xproj_mean['mean'][1:]/sum_hits_energy_every_bin_xproj_mean['energy'][1:], yerr = sum_hits_energy_every_bin_xproj_mean['sigma'][1:]/(sum_hits_energy_every_bin_xproj_mean['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'energy_every_bin_xproj_mean')
#plt.errorbar(np.sqrt(sum_hits_energy_every_bin_yproj_mean['energy'][1:]), sum_hits_energy_every_bin_yproj_mean['mean'][1:]/sum_hits_energy_every_bin_yproj_mean['energy'][1:], yerr = sum_hits_energy_every_bin_yproj_mean['sigma'][1:]/(np.sqrt(1990) * sum_hits_energy_every_bin_yproj_mean['energy'][1:]) ,fmt='-o', label = 'energy_every_bin_yproj_mean')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.56)
plt.ylim(0.98, 1.025)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_energy_corrected.png')
# Out:
# (0.98, 1.025)

# %%
#toy model

sum_hits_nhits_xproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_xproj_toy.txt')
sum_hits_nhits_yproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_yproj_toy.txt')
sum_hits_nhits_every_bin_xproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_every_bin_mean_xproj_toy.txt')
sum_hits_nhits_every_bin_yproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_every_bin_mean_yproj_toy.txt')

# %%
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_nhits_xproj_mean_toy['energy'][1:]), sum_hits_nhits_xproj_mean_toy['mean'][1:]/sum_hits_nhits_xproj_mean_toy['energy'][1:], yerr = sum_hits_nhits_xproj_mean_toy['sigma'][1:]/(sum_hits_nhits_xproj_mean_toy['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'nhits_xproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_nhits_yproj_mean_toy['energy'][1:]), sum_hits_nhits_yproj_mean_toy['mean'][1:]/sum_hits_nhits_yproj_mean_toy['energy'][1:], yerr = sum_hits_nhits_yproj_mean_toy['sigma'][1:]/(np.sqrt(1090) * sum_hits_nhits_yproj_mean_toy['energy'][1:]) ,fmt='-o', label = 'nhits_yproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_xproj_mean_toy['energy'][1:]), sum_hits_nhits_every_bin_xproj_mean_toy['mean'][1:]/sum_hits_nhits_every_bin_xproj_mean_toy['energy'][1:], yerr = sum_hits_nhits_every_bin_xproj_mean_toy['sigma'][1:]/(sum_hits_nhits_every_bin_xproj_mean_toy['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'nhits_every_bin_xproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_nhits_every_bin_yproj_mean_toy['energy'][1:]), sum_hits_nhits_every_bin_yproj_mean_toy['mean'][1:]/sum_hits_nhits_every_bin_yproj_mean_toy['energy'][1:], yerr = sum_hits_nhits_every_bin_yproj_mean_toy['sigma'][1:]/(np.sqrt(1990) * sum_hits_nhits_every_bin_yproj_mean_toy['energy'][1:]) ,fmt='-o', label = 'nhits_every_bin_yproj_mean_toy')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.8)
#plt.ylim(0.75, 1.25)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_nhits_cont_toy.png')

# %%
sum_hits_energy_xproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_xproj_toy.txt')
sum_hits_energy_yproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_yproj_toy.txt')
sum_hits_energy_every_bin_xproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_every_bin_mean_xproj_toy.txt')
sum_hits_energy_every_bin_yproj_mean_toy = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_energy_every_bin_mean_yproj_toy.txt')

# %%
plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_energy_xproj_mean_toy['energy'][1:]), sum_hits_energy_xproj_mean_toy['mean'][1:]/sum_hits_energy_xproj_mean_toy['energy'][1:], yerr = sum_hits_energy_xproj_mean_toy['sigma'][1:]/(sum_hits_energy_xproj_mean_toy['energy'][1:]*np.sqrt(1000)) ,fmt='-o', label = 'energy_xproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_energy_yproj_mean_toy['energy'][1:]), sum_hits_energy_yproj_mean_toy['mean'][1:]/sum_hits_energy_yproj_mean_toy['energy'][1:], yerr = sum_hits_energy_yproj_mean_toy['sigma'][1:]/(np.sqrt(1090) * sum_hits_energy_yproj_mean_toy['energy'][1:]) ,fmt='-o', label = 'energy_yproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_energy_every_bin_xproj_mean_toy['energy'][1:]), sum_hits_energy_every_bin_xproj_mean_toy['mean'][1:]/sum_hits_energy_every_bin_xproj_mean_toy['energy'][1:], yerr = sum_hits_energy_every_bin_xproj_mean_toy['sigma'][1:]/(sum_hits_energy_every_bin_xproj_mean_toy['energy'][1:]*np.sqrt(3000)) ,fmt='-o', label = 'energy_every_bin_xproj_mean_toy')
plt.errorbar(np.sqrt(sum_hits_energy_every_bin_yproj_mean_toy['energy'][1:]), sum_hits_energy_every_bin_yproj_mean_toy['mean'][1:]/sum_hits_energy_every_bin_yproj_mean_toy['energy'][1:], yerr = sum_hits_energy_every_bin_yproj_mean_toy['sigma'][1:]/(np.sqrt(1990) * sum_hits_energy_every_bin_yproj_mean_toy['energy'][1:]) ,fmt='-o', label = 'energy_every_bin_yproj_mean_toy')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.56)
plt.ylim(0.9, 1.41)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_energy_cont_toy.png')
