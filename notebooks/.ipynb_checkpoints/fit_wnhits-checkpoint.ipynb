# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from lmfit import Model

# %%
whits = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_mean_test.txt', header=0)

def func(x, a, b, c, d):
    return a*(x + b)**c + d

print(whits['mean'])
# Out:
# 0       10.1961
# 1       19.0515
# 2       25.3127
# 3       34.4227
# 4       61.1804
# 5      127.2620
# 6      183.1220
# 7      217.4650
# 8      363.2070
# 9      591.7270
# 10     775.6800
# 11     933.7590
# 12    1074.9800
# 13    1373.2700
# 14    1622.9900
# 15    1835.6300
# Name: mean, dtype: float64

# %%
plt.figure(figsize=(16,9))
plt.plot(whits['energy'], whits['mean'], 'o-')
plt.plot(whits['energy'], func(whits['energy'], 116, 3.5, 0.52, -220), 'o-')
plt.ylim(0,250)
plt.xlim(0,30)
# Out:
# (0.0, 30.0)

# %%
params, cov = curve_fit(func, xdata=whits['energy'], ydata=whits['mean'], p0=[152, 6.99, 0.48, -381.12])

# %%
plt.figure(figsize=(16,9))
plt.plot(whits['energy'], whits['mean'], 'o-')
plt.plot(whits['energy'], func(whits['energy'],params[0], params[1], params[2], params[3]), 'o-')
#plt.ylim(0,250)
#plt.xlim(0,30)

print(params)
# Out:
# [ 151.76835641    6.99193873    0.48360324 -381.12323312]

# %%
print(func(whits['energy'][0],params[0], params[1], params[2], params[3]))
# Out:
# 10.433410589478235

# %%
whits['mean'][0]
ydata = whits['mean']
xdata = whits['energy']

# %%
gmodel = Model(func)
params = gmodel.make_params(a=150, b=7, c=0.5, d=-100)
result=gmodel.fit(ydata, params, x=xdata)
print(result.fit_report())
# Out:
# [[Model]]
#     Model(func)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 16
#     # variables        = 4
#     chi-square         = 136.210649
#     reduced chi-square = 11.3508874
#     Akaike info crit   = 42.2658217
#     Bayesian info crit = 45.3561765
# [[Variables]]
#     a:  151.768700 +/- 11.7323166 (7.73%) (init = 150)
#     b:  6.99196505 +/- 0.85012106 (12.16%) (init = 7)
#     c:  0.48360292 +/- 0.01084756 (2.24%) (init = 0.5)
#     d: -381.124546 +/- 43.3208079 (11.37%) (init = -100)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(a, c) = -0.999
#     C(a, d) = -0.993
#     C(b, d) = -0.989
#     C(c, d) =  0.987
#     C(a, b) =  0.966
#     C(b, c) = -0.955

# %%
plt.figure(figsize=(14,8))
plt.plot(whits['energy'], whits['mean'], 'o-', label = 'data')
plt.plot(whits['energy'], result.best_fit, 'o-', label = 'fit')
plt.legend(fontsize=15)
plt.title('weighted nhits vs. energy', fontsize=15)
plt.xlabel('energy [GeV]', fontsize=15)
plt.ylabel('weighted number of hits', fontsize=15)
plt.grid()

# %%
plt.figure(figsize=(14,8))
#plt.plot(whits['energy'], whits['mean'], 'o-', label = 'data')
plt.plot(whits['energy'], (result.best_fit - whits['mean'])/whits['mean'], 'o-', label = 'relative difference')
plt.legend(fontsize=15)
plt.title('relative difference vs. energy', fontsize=15)
plt.xlabel('energy [GeV]', fontsize=15)
plt.ylabel('(fit - data)/(data)', fontsize=15)
plt.grid()

# %%
plt.figure(figsize=(14,8))
plt.plot(whits['energy'], whits['mean'], 'o-', label = 'data')
plt.plot(whits['energy'], result.best_fit, 'o-', label = 'fit')
plt.legend(fontsize=15)
plt.title('weighted nhits vs. energy', fontsize=15)
plt.xlabel('energy [GeV]', fontsize=15)
plt.ylabel('weighted number of hits', fontsize=15)
plt.grid()
plt.xlim(0,23)
plt.ylim(0,400)
# Out:
# (0.0, 400.0)
