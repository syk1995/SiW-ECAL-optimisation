# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
#number of hits
sum_hits_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_mean_test.txt', header=0)
sum_hits_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_test.txt', header=0)
sum_hits_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_test.txt', header=0)
sum_hits_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss2s_test.txt', header=0)
sum_hits_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms68_test.txt', header=0)
sum_hits_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms90_test.txt', header=0)
sum_hits_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_median_test.txt', header=0)
sum_hits_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gamma_test.txt', header=0)

'''
sum_hits_corrected_mean_y = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_corrected_new.txt')
sum_hits_corrected_gauss_y = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_corrected_new.txt')
sum_hits_corrected_every_bin_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_yproj.txt')
sum_hits_corrected_every_bin_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_yproj.txt')
sum_hits_corrected_every_bin_mean_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_xproj.txt')
sum_hits_corrected_every_bin_gauss_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_xproj.txt')
'''

#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_hits_mean['mean'], sum_hits_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.ylabel('Energy [GeV]', fontsize=17)
plt.xlabel('Number of Hits', fontsize=17)
plt.title('Number of Hits vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['mean']/sum_hits_corr_gauss2s['energy'], yerr = sum_hits_corr_gauss2s['mean_err']/sum_hits_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['mean']/sum_hits_corr_rms68['energy'], yerr = sum_hits_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_hits_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['mean']/sum_hits_corr_rms90['energy'], yerr = sum_hits_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_hits_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.errorbar(np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['mean']/sum_hits_corr_median['energy'], yerr = sum_hits_corr_median['sigma']/(np.sqrt(4990) * sum_hits_corr_median['energy']) ,fmt='-o', label = 'median')
plt.errorbar(np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['mean']/sum_hits_corr_gamma['energy'], yerr = sum_hits_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['sigma']/sum_hits_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['sigma']/sum_hits_corr_rms90['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['sigma']/sum_hits_corr_median['mean'] , 'o-', label = 'median')
plt.plot(1/np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['sigma']/sum_hits_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits.png')

'''
#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_hits_corr_gauss['energy'], sum_hits_corr_gauss['mean'], yerr = sum_hits_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_hits_corr_mean['energy'], sum_hits_corr_mean['mean'], yerr = sum_hits_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_hits_corr_gauss2s['energy'], sum_hits_corr_gauss2s['mean'], yerr = sum_hits_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_hits_corr_rms68['energy'], sum_hits_corr_rms68['mean'], yerr = sum_hits_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_hits_corr_median['energy'], sum_hits_corr_median['mean'], yerr = sum_hits_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'Median')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nhits.png')
'''


plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_corrected_gauss['energy'][1:]), sum_hits_corrected_gauss['mean'][1:]/sum_hits_corrected_gauss['energy'][1:], yerr = sum_hits_corrected_gauss['sigma'][1:]/(sum_hits_corrected_gauss['energy'][1:]*3000) ,fmt='-o', label = 'gauss continuous')
plt.errorbar(np.sqrt(sum_hits_corrected_mean['energy'][1:]), sum_hits_corrected_mean['mean'][1:]/sum_hits_corrected_mean['energy'][1:], yerr = sum_hits_corrected_mean['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean['energy'][1:]) ,fmt='-o', label = 'mean continuous')
plt.errorbar(np.sqrt(sum_hits_corrected_gauss_y['energy'][1:]), sum_hits_corrected_gauss_y['mean'][1:]/sum_hits_corrected_gauss_y['energy'][1:], yerr = sum_hits_corrected_gauss_y['sigma'][1:]/(sum_hits_corrected_gauss_y['energy'][1:]*3000) ,fmt='-o', label = 'gauss corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_mean_y['energy'][1:]), sum_hits_corrected_mean_y['mean'][1:]/sum_hits_corrected_mean_y['energy'][1:], yerr = sum_hits_corrected_mean_y['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean_y['energy'][1:]) ,fmt='-o', label = 'mean corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean['energy'][1:]), sum_hits_corrected_every_bin_mean['mean'][1:]/sum_hits_corrected_every_bin_mean['energy'][1:], yerr = sum_hits_corrected_every_bin_mean['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean['energy'][1:]) ,fmt='-', label = 'every bin mean y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss['energy'][1:]), sum_hits_corrected_every_bin_gauss['mean'][1:]/sum_hits_corrected_every_bin_gauss['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss['energy'][1:]) ,fmt='-', label = 'every bin gauss y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean_x['energy'][1:]), sum_hits_corrected_every_bin_mean_x['mean'][1:]/sum_hits_corrected_every_bin_mean_x['energy'][1:], yerr = sum_hits_corrected_every_bin_mean_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean_x['energy'][1:]) ,fmt='-', label = 'every bin mean x proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['mean'][1:]/sum_hits_corrected_every_bin_gauss_x['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss_x['energy'][1:]) ,fmt='-', label = 'every bin gauss x proj')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,2.2)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_corrected.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_corrected_gauss['energy']), sum_hits_corrected_gauss['sigma']/sum_hits_corrected_gauss['mean'], 'o-', label = 'gauss corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_mean['energy']), sum_hits_corrected_mean['sigma']/sum_hits_corrected_mean['mean'], 'o-', label = 'mean corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['sigma']/sum_hits_corrected_every_bin_mean['mean'], '-', label = 'every bin mean')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss['energy']), sum_hits_corrected_every_bin_gauss['sigma']/sum_hits_corrected_every_bin_gauss['mean'], '-', label = 'every bin gauss')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['sigma']/sum_hits_corrected_every_bin_mean_x['mean'], '-', label = 'every bin mean x proj')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/sum_hits_corrected_every_bin_gauss_x['mean'][1:], '-', label = 'every bin gauss x proj')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 1)
plt.legend(fontsize=15)
#plt.ylim(0, 0.2)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_corrected.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-88f8dd49fbbf> in <module>
#      87 plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
#      88 plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
# ---> 89 plt.errorbar(np.sqrt(sum_hits_corrected_gauss['energy'][1:]), sum_hits_corrected_gauss['mean'][1:]/sum_hits_corrected_gauss['energy'][1:], yerr = sum_hits_corrected_gauss['sigma'][1:]/(sum_hits_corrected_gauss['energy'][1:]*3000) ,fmt='-o', label = 'gauss continuous')
# ...

# %%
#number of hits
sum_hits_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_mean_test.txt', header=0)
sum_hits_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_test.txt', header=0)
sum_hits_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_test.txt', header=0)
sum_hits_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss2s_test.txt', header=0)
sum_hits_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms68_test.txt', header=0)
sum_hits_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms90_test.txt', header=0)
sum_hits_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_median_test.txt', header=0)
sum_hits_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gamma_test.txt', header=0)

sum_hits_corrected_mean_y = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_nhits_yproj.txt')
sum_hits_corrected_gauss_y = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_nhits_yproj_gauss.txt')
sum_hits_corrected_every_bin_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_yproj.txt')
sum_hits_corrected_every_bin_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_yproj.txt')
sum_hits_corrected_every_bin_mean_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_xproj.txt')
sum_hits_corrected_every_bin_gauss_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_xproj.txt')



plt.figure(figsize=(16,9))
plt.plot(sum_hits_mean['mean'], sum_hits_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.ylabel('Energy [GeV]', fontsize=17)
plt.xlabel('Number of Hits', fontsize=17)
plt.title('Number of Hits vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['mean']/sum_hits_corr_gauss2s['energy'], yerr = sum_hits_corr_gauss2s['mean_err']/sum_hits_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['mean']/sum_hits_corr_rms68['energy'], yerr = sum_hits_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_hits_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['mean']/sum_hits_corr_rms90['energy'], yerr = sum_hits_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_hits_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.errorbar(np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['mean']/sum_hits_corr_median['energy'], yerr = sum_hits_corr_median['sigma']/(np.sqrt(4990) * sum_hits_corr_median['energy']) ,fmt='-o', label = 'median')
plt.errorbar(np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['mean']/sum_hits_corr_gamma['energy'], yerr = sum_hits_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['sigma']/sum_hits_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['sigma']/sum_hits_corr_rms90['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['sigma']/sum_hits_corr_median['mean'] , 'o-', label = 'median')
plt.plot(1/np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['sigma']/sum_hits_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits.png')

'''
#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_hits_corr_gauss['energy'], sum_hits_corr_gauss['mean'], yerr = sum_hits_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_hits_corr_mean['energy'], sum_hits_corr_mean['mean'], yerr = sum_hits_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_hits_corr_gauss2s['energy'], sum_hits_corr_gauss2s['mean'], yerr = sum_hits_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_hits_corr_rms68['energy'], sum_hits_corr_rms68['mean'], yerr = sum_hits_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_hits_corr_median['energy'], sum_hits_corr_median['mean'], yerr = sum_hits_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'Median')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nhits.png')
'''


plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_hits_corrected_gauss['energy'][1:]), sum_hits_corrected_gauss['mean'][1:]/sum_hits_corrected_gauss['energy'][1:], yerr = sum_hits_corrected_gauss['sigma'][1:]/(sum_hits_corrected_gauss['energy'][1:]*3000) ,fmt='-o', label = 'gauss continuous')
#plt.errorbar(np.sqrt(sum_hits_corrected_mean['energy'][1:]), sum_hits_corrected_mean['mean'][1:]/sum_hits_corrected_mean['energy'][1:], yerr = sum_hits_corrected_mean['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean['energy'][1:]) ,fmt='-o', label = 'mean continuous')
#plt.errorbar(np.sqrt(sum_hits_corrected_gauss_y['energy'][1:]), sum_hits_corrected_gauss_y['mean'][1:]/sum_hits_corrected_gauss_y['energy'][1:], yerr = sum_hits_corrected_gauss_y['sigma'][1:]/(sum_hits_corrected_gauss_y['energy'][1:]*3000) ,fmt='-o', label = 'gauss corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_mean_y['energy'][1:]), sum_hits_corrected_mean_y['mean'][1:]/sum_hits_corrected_mean_y['energy'][1:], yerr = sum_hits_corrected_mean_y['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean_y['energy'][1:]) ,fmt='-o', label = 'mean corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['mean']/sum_hits_corrected_every_bin_mean['energy'], yerr = sum_hits_corrected_every_bin_mean['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean['energy']) ,fmt='-', label = 'every bin mean y proj')
#plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss['energy'][1:]), sum_hits_corrected_every_bin_gauss['mean'][1:]/sum_hits_corrected_every_bin_gauss['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss['energy'][1:]) ,fmt='-', label = 'every bin gauss y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean_x['energy'][1:]), sum_hits_corrected_every_bin_mean_x['mean'][1:]/sum_hits_corrected_every_bin_mean_x['energy'][1:], yerr = sum_hits_corrected_every_bin_mean_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean_x['energy'][1:]) ,fmt='-', label = 'every bin mean x proj')
#plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['mean'][1:]/sum_hits_corrected_every_bin_gauss_x['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss_x['energy'][1:]) ,fmt='-', label = 'every bin gauss x proj')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.8)
#plt.ylim(0.75, 1.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_corrected.png')

plt.figure(figsize=(14,7), facecolor='white')
#plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
#plt.plot(1/np.sqrt(sum_hits_corrected_gauss['energy']), sum_hits_corrected_gauss['sigma']/sum_hits_corrected_gauss['mean'], 'o-', label = 'gauss corrected')
#plt.plot(1/np.sqrt(sum_hits_corrected_mean['energy']), sum_hits_corrected_mean['sigma']/sum_hits_corrected_mean['mean'], 'o-', label = 'mean corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_mean_y['energy']), sum_hits_corrected_mean_y['sigma']/sum_hits_corrected_mean_y['mean'], 'o-', label = 'mean corrected y')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['sigma']/sum_hits_corrected_every_bin_mean['mean'], '-', label = 'every bin mean')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss['energy']), sum_hits_corrected_every_bin_gauss['sigma']/sum_hits_corrected_every_bin_gauss['mean'], '-', label = 'every bin gauss')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['sigma']/sum_hits_corrected_every_bin_mean_x['mean'], '-', label = 'every bin mean x proj')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/sum_hits_corrected_every_bin_gauss_x['mean'][1:], '-', label = 'every bin gauss x proj')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlim(0, 2)
plt.legend(fontsize=15)
plt.ylim(0, 0.4)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_corrected.png')
# Out:
# (0.0, 0.4)

# %%
plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_corrected_gauss['energy']), sum_hits_corrected_gauss['mean']/sum_hits_corrected_gauss['energy'], yerr = sum_hits_corrected_gauss['sigma']/(sum_hits_corrected_gauss['energy']*3000) ,fmt='-o', label = 'gauss continuous')
plt.errorbar(np.sqrt(sum_hits_corrected_mean['energy']), sum_hits_corrected_mean['mean']/sum_hits_corrected_mean['energy'], yerr = sum_hits_corrected_mean['sigma']/(np.sqrt(4990) * sum_hits_corrected_mean['energy']) ,fmt='-o', label = 'mean continuous')
plt.errorbar(np.sqrt(sum_hits_corrected_gauss_y['energy']), sum_hits_corrected_gauss_y['mean']/sum_hits_corrected_gauss_y['energy'], yerr = sum_hits_corrected_gauss_y['sigma']/(sum_hits_corrected_gauss_y['energy']*3000) ,fmt='-o', label = 'gauss corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_mean_y['energy']), sum_hits_corrected_mean_y['mean']/sum_hits_corrected_mean_y['energy'], yerr = sum_hits_corrected_mean_y['sigma']/(np.sqrt(4990) * sum_hits_corrected_mean_y['energy']) ,fmt='-o', label = 'mean corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['mean']/sum_hits_corrected_every_bin_mean['energy'], yerr = sum_hits_corrected_every_bin_mean['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean['energy']) ,fmt='-', label = 'every bin mean y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss['energy']), sum_hits_corrected_every_bin_gauss['mean']/sum_hits_corrected_every_bin_gauss['energy'], yerr = sum_hits_corrected_every_bin_gauss['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss['energy']) ,fmt='-', label = 'every bin gauss y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['mean']/sum_hits_corrected_every_bin_mean_x['energy'], yerr = sum_hits_corrected_every_bin_mean_x['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean_x['energy']) ,fmt='-', label = 'every bin mean x proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['mean'][1:]/sum_hits_corrected_every_bin_gauss_x['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss_x['energy'][1:]) ,fmt='-', label = 'every bin gauss x proj')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,2.2)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_corrected.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_corrected_gauss['energy']), sum_hits_corrected_gauss['sigma']/sum_hits_corrected_gauss['mean'], 'o-', label = 'gauss corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_mean['energy']), sum_hits_corrected_mean['sigma']/sum_hits_corrected_mean['mean'], 'o-', label = 'mean corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['sigma']/sum_hits_corrected_every_bin_mean['mean'], '-', label = 'every bin mean')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss['energy']), sum_hits_corrected_every_bin_gauss['sigma']/sum_hits_corrected_every_bin_gauss['mean'], '-', label = 'every bin gauss')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['sigma']/sum_hits_corrected_every_bin_mean_x['mean'], '-', label = 'every bin mean x proj')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/sum_hits_corrected_every_bin_gauss_x['mean'][1:], '-', label = 'every bin gauss x proj')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 1)
plt.legend(fontsize=15)
#plt.ylim(0, 0.2)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_corrected.png')

# %%
#number of hits
sum_hits_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_mean_test.txt', header=0)
sum_hits_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_test.txt', header=0)
sum_hits_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_test.txt', header=0)
sum_hits_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss2s_test.txt', header=0)
sum_hits_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms68_test.txt', header=0)
sum_hits_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms90_test.txt', header=0)
sum_hits_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_median_test.txt', header=0)
sum_hits_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gamma_test.txt', header=0)

sum_hits_corrected_mean_y_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_corrected_new_xproj.txt')
sum_hits_corrected_gauss_y_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_corrected_new_xproj.txt')
sum_hits_corrected_every_bin_mean_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_yproj_xproj.txt')
sum_hits_corrected_every_bin_gauss_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_yproj_xproj.txt')
sum_hits_corrected_every_bin_mean_x_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_mean_xproj_xproj.txt')
sum_hits_corrected_every_bin_gauss_x_x = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_every_bin_gauss_xproj_xproj.txt')



plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_hits_corrected_gauss['energy'][1:]), sum_hits_corrected_gauss['mean'][1:]/sum_hits_corrected_gauss['energy'][1:], yerr = sum_hits_corrected_gauss['sigma'][1:]/(sum_hits_corrected_gauss['energy'][1:]*3000) ,fmt='-o', label = 'gauss continuous')
#plt.errorbar(np.sqrt(sum_hits_corrected_mean['energy'][1:]), sum_hits_corrected_mean['mean'][1:]/sum_hits_corrected_mean['energy'][1:], yerr = sum_hits_corrected_mean['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean['energy'][1:]) ,fmt='-o', label = 'mean continuous')
#plt.errorbar(np.sqrt(sum_hits_corrected_gauss_y['energy'][1:]), sum_hits_corrected_gauss_y['mean'][1:]/sum_hits_corrected_gauss_y['energy'][1:], yerr = sum_hits_corrected_gauss_y['sigma'][1:]/(sum_hits_corrected_gauss_y['energy'][1:]*3000) ,fmt='-o', label = 'gauss corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_mean_y_x['energy'][1:]), sum_hits_corrected_mean_y_x['mean'][1:]/sum_hits_corrected_mean_y_x['energy'][1:], yerr = sum_hits_corrected_mean_y_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_mean_y_x['energy'][1:]) ,fmt='-o', label = 'mean corrected y')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['mean']/sum_hits_corrected_every_bin_mean_x['energy'], yerr = sum_hits_corrected_every_bin_mean_x['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean_x['energy']) ,fmt='-', label = 'every bin mean y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean['energy']), sum_hits_corrected_every_bin_mean['mean']/sum_hits_corrected_every_bin_mean['energy'], yerr = sum_hits_corrected_every_bin_mean['sigma']/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean['energy']) ,fmt='-', label = 'every bin mean y y proj')
#plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss['energy'][1:]), sum_hits_corrected_every_bin_gauss['mean'][1:]/sum_hits_corrected_every_bin_gauss['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss['energy'][1:]) ,fmt='-', label = 'every bin gauss y proj')
plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_mean_x_x['energy'][1:]), sum_hits_corrected_every_bin_mean_x_x['mean'][1:]/sum_hits_corrected_every_bin_mean_x_x['energy'][1:], yerr = sum_hits_corrected_every_bin_mean_x_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_mean_x_x['energy'][1:]) ,fmt='-', label = 'every bin mean x proj')
#plt.errorbar(np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['mean'][1:]/sum_hits_corrected_every_bin_gauss_x['energy'][1:], yerr = sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/(np.sqrt(4990) * sum_hits_corrected_every_bin_gauss_x['energy'][1:]) ,fmt='-', label = 'every bin gauss x proj')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,3.8)
plt.ylim(0.75, 1.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_corrected.png')

plt.figure(figsize=(14,7), facecolor='white')
#plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
#plt.plot(1/np.sqrt(sum_hits_corrected_gauss['energy']), sum_hits_corrected_gauss['sigma']/sum_hits_corrected_gauss['mean'], 'o-', label = 'gauss corrected')
#plt.plot(1/np.sqrt(sum_hits_corrected_mean['energy']), sum_hits_corrected_mean['sigma']/sum_hits_corrected_mean['mean'], 'o-', label = 'mean corrected')
plt.plot(1/np.sqrt(sum_hits_corrected_mean_y_x['energy']), sum_hits_corrected_mean_y_x['sigma']/sum_hits_corrected_mean_y_x['mean'], 'o-', label = 'mean corrected y')
plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['sigma']/sum_hits_corrected_every_bin_mean_x['mean'], '-', label = 'every bin mean')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss['energy']), sum_hits_corrected_every_bin_gauss['sigma']/sum_hits_corrected_every_bin_gauss['mean'], '-', label = 'every bin gauss')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_mean_x['energy']), sum_hits_corrected_every_bin_mean_x['sigma']/sum_hits_corrected_every_bin_mean_x['mean'], '-', label = 'every bin mean x proj')
#plt.plot(1/np.sqrt(sum_hits_corrected_every_bin_gauss_x['energy'][1:]), sum_hits_corrected_every_bin_gauss_x['sigma'][1:]/sum_hits_corrected_every_bin_gauss_x['mean'][1:], '-', label = 'every bin gauss x proj')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 2)
plt.legend(fontsize=15)
#plt.ylim(0, 0.4)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_corrected.png')

# %%
#number of hits
sum_hits_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_mean_test.txt', header=0)
sum_hits_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss_test.txt', header=0)
sum_hits_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_mean_test.txt', header=0)
sum_hits_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gauss2s_test.txt', header=0)
#sum_hits_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms68_test.txt', header=0)
sum_hits_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_rms90_test.txt', header=0)
sum_hits_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_median_test.txt', header=0)
sum_hits_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_corr_gamma_test.txt', header=0)




#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_hits_mean['mean'], sum_hits_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.ylabel('Energy [GeV]', fontsize=17)
plt.xlabel('Number of Hits', fontsize=17)
plt.title('Number of Hits vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['mean']/sum_hits_corr_gauss2s['energy'], yerr = sum_hits_corr_gauss2s['mean_err']/sum_hits_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['mean']/sum_hits_corr_rms68['energy'], yerr = sum_hits_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_hits_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['mean']/sum_hits_corr_rms90['energy'], yerr = sum_hits_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_hits_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.errorbar(np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['mean']/sum_hits_corr_median['energy'], yerr = sum_hits_corr_median['sigma']/(np.sqrt(4990) * sum_hits_corr_median['energy']) ,fmt='-o', label = 'median')
plt.errorbar(np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['mean']/sum_hits_corr_gamma['energy'], yerr = sum_hits_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['sigma']/sum_hits_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_hits_corr_rms90['energy']), sum_hits_corr_rms90['sigma']/sum_hits_corr_rms90['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['sigma']/sum_hits_corr_median['mean'] , 'o-', label = 'median')
plt.plot(1/np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['sigma']/sum_hits_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits.png')

#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_hits_corr_gauss['energy'], sum_hits_corr_gauss['mean'], yerr = sum_hits_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_hits_corr_mean['energy'], sum_hits_corr_mean['mean'], yerr = sum_hits_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_hits_corr_gauss2s['energy'], sum_hits_corr_gauss2s['mean'], yerr = sum_hits_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_hits_corr_rms68['energy'], sum_hits_corr_rms68['mean'], yerr = sum_hits_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_hits_corr_median['energy'], sum_hits_corr_median['mean'], yerr = sum_hits_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'Median')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nhits.png')

# %%
#number of hits
sum_hits_weighted_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_mean_test.txt', header=0)
sum_hits_weighted_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gauss_test.txt', header=0)
sum_hits_weighted_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_mean_test.txt', header=0)
sum_hits_weighted_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gauss2s_test.txt', header=0)
sum_hits_weighted_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_rms68_test.txt', header=0)
sum_hits_weighted_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_rms90_test.txt', header=0)
sum_hits_weighted_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_median_test.txt', header=0)
sum_hits_weighted_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gamma_test.txt', header=0)





#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_hits_weighted_mean['mean'], sum_hits_weighted_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.ylabel('Energy [GeV]', fontsize=17)
plt.xlabel('Number of Hits', fontsize=17)
plt.title('Number of Hits vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss not weighted')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['mean']/sum_hits_weighted_corr_gauss['energy'], yerr = sum_hits_weighted_corr_gauss['mean_err']/sum_hits_weighted_corr_gauss['energy'] ,fmt='-o', label = 'gauss weighted')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean not weighted')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'mean weighted')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['mean']/sum_hits_corr_gauss2s['energy'], yerr = sum_hits_corr_gauss2s['mean_err']/sum_hits_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_gauss2s['energy']), sum_hits_weighted_corr_gauss2s['mean']/sum_hits_weighted_corr_gauss2s['energy'], yerr = sum_hits_weighted_corr_gauss2s['mean_err']/sum_hits_weighted_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_rms68['energy']), sum_hits_weighted_corr_rms68['mean']/sum_hits_weighted_corr_rms68['energy'], yerr = sum_hits_weighted_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_hits_weighted_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_rms90['energy']), sum_hits_weighted_corr_rms90['mean']/sum_hits_weighted_corr_rms90['energy'], yerr = sum_hits_weighted_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_hits_weighted_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
#plt.errorbar(np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['mean']/sum_hits_corr_median['energy'], yerr = sum_hits_corr_median['sigma']/(np.sqrt(4990) * sum_hits_corr_median['energy']) ,fmt='-o', label = 'median weighted')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_median['energy']), sum_hits_weighted_corr_median['mean']/sum_hits_weighted_corr_median['energy'], yerr = sum_hits_weighted_corr_median['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_median['energy']) ,fmt='-o', label = 'median')
#plt.errorbar(np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['mean']/sum_hits_corr_gamma['energy'], yerr = sum_hits_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_gamma['energy']), sum_hits_weighted_corr_gamma['mean']/sum_hits_weighted_corr_gamma['energy'], yerr = sum_hits_weighted_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Weighted Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_comparison.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['sigma']/sum_hits_weighted_corr_gauss['mean'], 'o-', label = 'gauss weighted')
plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss not weighted')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], 'o-', label = 'mean weighted')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean not weighted')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_gauss2s['energy']), sum_hits_weighted_corr_gauss2s['sigma']/sum_hits_weighted_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_rms68['energy']), sum_hits_weighted_corr_rms68['sigma']/sum_hits_weighted_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_rms90['energy']), sum_hits_weighted_corr_rms90['sigma']/sum_hits_weighted_corr_rms90['mean'] , 'o-', label = 'RMS98')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_median['energy']), sum_hits_weighted_corr_median['sigma']/sum_hits_weighted_corr_median['mean'] , 'o-', label = 'median')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_gamma['energy']), sum_hits_weighted_corr_gamma['sigma']/sum_hits_weighted_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for weighted number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_comparison.png')

#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_hits_weighted_corr_gauss['energy'], sum_hits_weighted_corr_gauss['mean'], yerr = sum_hits_weighted_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_hits_weighted_corr_mean['energy'], sum_hits_weighted_corr_mean['mean'], yerr = sum_hits_weighted_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_hits_weighted_corr_gauss2s['energy'], sum_hits_weighted_corr_gauss2s['mean'], yerr = sum_hits_weighted_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(sum_hits_weighted_corr_rms68['energy'], sum_hits_weighted_corr_rms68['mean'], yerr = sum_hits_weighted_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_hits_weighted_corr_median['energy'], sum_hits_weighted_corr_median['mean'], yerr = sum_hits_weighted_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'Median')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nhits.png')


plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['mean']/sum_hits_weighted_corr_gauss['energy'], yerr = sum_hits_weighted_corr_gauss['sigma']/(5000*sum_hits_weighted_corr_gauss['energy']) ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_weighted_corrected_gauss['energy']), sum_hits_weighted_corrected_gauss['mean']/sum_hits_weighted_corrected_gauss['energy'], yerr = sum_hits_weighted_corrected_gauss['sigma']/(sum_hits_weighted_corrected_gauss['energy']*3000) ,fmt='-o', label = 'gauss corrected')
plt.errorbar(np.sqrt(sum_hits_weighted_corrected_mean['energy']), sum_hits_weighted_corrected_mean['mean']/sum_hits_weighted_corrected_mean['energy'], yerr = sum_hits_weighted_corrected_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corrected_mean['energy']) ,fmt='-o', label = 'mean corrected')
plt.title('Linearity Plot for Weighted Number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
plt.xlim(0,2.2)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_weighted_corrected.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['sigma']/sum_hits_weighted_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_weighted_corrected_gauss['energy']), sum_hits_weighted_corrected_gauss['sigma']/sum_hits_weighted_corrected_gauss['mean'], 'o-', label = 'gauss corrected')
plt.plot(1/np.sqrt(sum_hits_weighted_corrected_mean['energy']), sum_hits_weighted_corrected_mean['sigma']/sum_hits_weighted_corrected_mean['mean'], 'o-', label = 'mean corrected')
plt.grid()
plt.title('Resolution Plot for Weighted Number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits_weighted_corrected.png')

# %%
#number of hits
sum_hits_weighted_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_mean_test.txt', header=0)
sum_hits_weighted_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gauss_test.txt', header=0)
sum_hits_weighted_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_mean_test.txt', header=0)
sum_hits_weighted_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gauss2s_test.txt', header=0)
#sum_hits_weighted_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_rms68_test.txt', header=0)
sum_hits_weighted_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_rms90_test.txt', header=0)
sum_hits_weighted_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_median_test.txt', header=0)
sum_hits_weighted_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_corr_gamma_test.txt', header=0)




#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_hits_weighted_mean['mean'], sum_hits_weighted_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.ylabel('Energy [GeV]', fontsize=17)
plt.xlabel('Number of Hits', fontsize=17)
plt.title('Number of Hits vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['mean']/sum_hits_corr_gauss['energy'], yerr = sum_hits_corr_gauss['mean_err']/sum_hits_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['mean']/sum_hits_weighted_corr_gauss['energy'], yerr = sum_hits_weighted_corr_gauss['mean_err']/sum_hits_weighted_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
#plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_hits_corr_gauss2s['energy']), sum_hits_corr_gauss2s['mean']/sum_hits_corr_gauss2s['energy'], yerr = sum_hits_corr_gauss2s['mean_err']/sum_hits_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_gauss2s['energy']), sum_hits_weighted_corr_gauss2s['mean']/sum_hits_weighted_corr_gauss2s['energy'], yerr = sum_hits_weighted_corr_gauss2s['mean_err']/sum_hits_weighted_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_rms68['energy']), sum_hits_weighted_corr_rms68['mean']/sum_hits_weighted_corr_rms68['energy'], yerr = sum_hits_weighted_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_hits_weighted_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_rms90['energy']), sum_hits_weighted_corr_rms90['mean']/sum_hits_weighted_corr_rms90['energy'], yerr = sum_hits_weighted_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_hits_weighted_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
#plt.errorbar(np.sqrt(sum_hits_corr_median['energy']), sum_hits_corr_median['mean']/sum_hits_corr_median['energy'], yerr = sum_hits_corr_median['sigma']/(np.sqrt(4990) * sum_hits_corr_median['energy']) ,fmt='-o', label = 'median weighted')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_median['energy']), sum_hits_weighted_corr_median['mean']/sum_hits_weighted_corr_median['energy'], yerr = sum_hits_weighted_corr_median['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_median['energy']) ,fmt='-o', label = 'median')
#plt.errorbar(np.sqrt(sum_hits_corr_gamma['energy']), sum_hits_corr_gamma['mean']/sum_hits_corr_gamma['energy'], yerr = sum_hits_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
#plt.errorbar(np.sqrt(sum_hits_weighted_corr_gamma['energy']), sum_hits_weighted_corr_gamma['mean']/sum_hits_weighted_corr_gamma['energy'], yerr = sum_hits_weighted_corr_gamma['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for weighted number of Hits', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_nhits_weighted.png')

plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_gauss['energy']), sum_hits_weighted_corr_gauss['sigma']/sum_hits_weighted_corr_gauss['mean'], 'o-', label = 'gauss weighted')
#plt.plot(1/np.sqrt(sum_hits_corr_gauss['energy']), sum_hits_corr_gauss['sigma']/sum_hits_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], 'o-', label = 'mean weighted')
#plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'mean')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_gauss2s['energy']), sum_hits_weighted_corr_gauss2s['sigma']/sum_hits_weighted_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_rms68['energy']), sum_hits_weighted_corr_rms68['sigma']/sum_hits_weighted_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_rms90['energy']), sum_hits_weighted_corr_rms90['sigma']/sum_hits_weighted_corr_rms90['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_median['energy']), sum_hits_weighted_corr_median['sigma']/sum_hits_weighted_corr_median['mean'] , 'o-', label = 'median')
#plt.plot(1/np.sqrt(sum_hits_weighted_corr_gamma['energy']), sum_hits_weighted_corr_gamma['sigma']/sum_hits_weighted_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for weighted number of Hits', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_nhits.png')

#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_hits_weighted_corr_gauss['energy'], sum_hits_weighted_corr_gauss['mean'], yerr = sum_hits_weighted_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_hits_weighted_corr_mean['energy'], sum_hits_weighted_corr_mean['mean'], yerr = sum_hits_weighted_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_hits_weighted_corr_gauss2s['energy'], sum_hits_weighted_corr_gauss2s['mean'], yerr = sum_hits_weighted_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(sum_hits_weighted_corr_rms68['energy'], sum_hits_weighted_corr_rms68['mean'], yerr = sum_hits_weighted_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_hits_weighted_corr_median['energy'], sum_hits_weighted_corr_median['mean'], yerr = sum_hits_weighted_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'Median')
plt.title('Linearity Plot for Number of Hits', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nhits.png')

# %%
sum_hits_weighted_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_energy_mean_test.txt', header=0)
sum_hits_weighted_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_hits_weighted_energy_gauss_test.txt', header=0)
par = np.array([-2.66907e-08, 0.000159691, 0.032614, -1.56747e-08, 0.000137639, 0.0365951, -1.14926e-08, 0.000124234, 0.0384119]);

alpha = lambda x: par[0] * x**2 + par[1]*x + par[2]
beta = lambda x: par[3] * x**2 + par[4] * x + par[5]
gamma = lambda x: par[6] * x**2 + par[7] * x + par[8]

nhits = np.arange(4000)

plt.figure(figsize=(14,7))
plt.plot(nhits, alpha(nhits), label = 'alpha')
plt.plot(nhits, beta(nhits), label = 'beta')
plt.plot(nhits, gamma(nhits), label = 'gamma')
plt.title('weights', fontsize=15)
plt.xlabel('number of hits', fontsize = 15)
plt.ylabel('weight', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()


plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_hits_weighted_mean['energy']), sum_hits_weighted_mean['mean']/sum_hits_weighted_mean['energy'], yerr = sum_hits_weighted_mean['sigma']/(5000*sum_hits_weighted_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_hits_weighted_gauss['energy']), sum_hits_weighted_gauss['mean']/sum_hits_weighted_gauss['energy'], yerr = sum_hits_weighted_gauss['sigma']/(5000*sum_hits_weighted_gauss['energy']) ,fmt='-o', label = 'gauss')
plt.title('Linearity Plot for weighted number of hits (energy)', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_weighted_mean['energy']), sum_hits_weighted_mean['sigma']/sum_hits_weighted_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_hits_weighted_gauss['energy']), sum_hits_weighted_gauss['sigma']/sum_hits_weighted_gauss['mean'], 'o-', label = 'gauss')
plt.grid()
plt.title('Resolution Plot for weighted number of hits (energy)', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy.png')

# %%
#number of energy
sum_energy_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_mean.txt', header=0)
sum_energy_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_gauss.txt', header=0)
sum_energy_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_mean.txt', header=0)
sum_energy_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_gauss2s.txt', header=0)
sum_energy_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_rms68.txt', header=0)
sum_energy_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_rms90.txt', header=0)


#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_mean['mean'], sum_energy_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('sum energy', fontsize=17)
plt.title('sum energy vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_corr_gauss['energy']), sum_energy_corr_gauss['mean']/sum_energy_corr_gauss['energy'], yerr = sum_energy_corr_gauss['mean_err']/sum_energy_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['mean']/sum_energy_corr_mean['energy'], yerr = sum_energy_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_energy_corr_gauss2s['energy']), sum_energy_corr_gauss2s['mean']/sum_energy_corr_gauss2s['energy'], yerr = sum_energy_corr_gauss2s['mean_err']/sum_energy_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(np.sqrt(sum_energy_corr_rms68['energy']), sum_energy_corr_rms68['mean']/sum_energy_corr_rms68['energy'], yerr = sum_energy_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_energy_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
plt.errorbar(np.sqrt(sum_energy_corr_rms90['energy']), sum_energy_corr_rms90['mean']/sum_energy_corr_rms90['energy'], yerr = sum_energy_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_energy_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.title('Linearity Plot for Sum Energy', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_corr_gauss['energy']), sum_energy_corr_gauss['sigma']/sum_energy_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['sigma']/sum_energy_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_energy_corr_gauss2s['energy']), sum_energy_corr_gauss2s['sigma']/sum_energy_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
plt.plot(1/np.sqrt(sum_energy_corr_rms68['energy']), sum_energy_corr_rms68['sigma']/sum_energy_corr_rms68['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_energy_corr_rms90['energy']), sum_energy_corr_rms90['sigma']/sum_energy_corr_rms90['mean'] , 'o-', label = 'RMS90')
plt.grid()
plt.title('Resolution Plot for Sum Energy', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy.png')


#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_corr_gauss['energy'], sum_energy_corr_gauss['mean'], yerr = sum_energy_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_corr_mean['energy'], sum_energy_corr_mean['mean'], yerr = sum_energy_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_corr_gauss2s['energy'], sum_energy_corr_gauss2s['mean'], yerr = sum_energy_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_corr_rms68['energy'], sum_energy_corr_rms68['mean'], yerr = sum_energy_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for sum energy', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy.png')

# %%
#number of energy
sum_energy_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_mean_test.txt', header=0)
sum_energy_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_gauss_test.txt', header=0)
sum_energy_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_mean_test.txt', header=0)
sum_energy_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_gauss2s_test.txt', header=0)
sum_energy_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_rms68_test.txt', header=0)
sum_energy_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_rms90_test.txt', header=0)
sum_energy_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_median_test.txt', header=0)
sum_energy_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_corr_gamma_test.txt', header=0)



#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_mean['mean'], sum_energy_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('sum energy', fontsize=17)
plt.title('sum energy vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_corr_gauss['energy']), sum_energy_corr_gauss['mean']/sum_energy_corr_gauss['energy'], yerr = sum_energy_corr_gauss['mean_err']/sum_energy_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['mean']/sum_energy_corr_mean['energy'], yerr = sum_energy_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_energy_corr_gauss2s['energy']), sum_energy_corr_gauss2s['mean']/sum_energy_corr_gauss2s['energy'], yerr = sum_energy_corr_gauss2s['mean_err']/sum_energy_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(np.sqrt(sum_energy_corr_rms68['energy']), sum_energy_corr_rms68['mean']/sum_energy_corr_rms68['energy'], yerr = sum_energy_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_energy_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
plt.errorbar(np.sqrt(sum_energy_corr_rms90['energy']), sum_energy_corr_rms90['mean']/sum_energy_corr_rms90['energy'], yerr = sum_energy_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_energy_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.errorbar(np.sqrt(sum_energy_corr_median['energy']), sum_energy_corr_median['mean']/sum_energy_corr_median['energy'], yerr = sum_energy_corr_median['sigma']/(np.sqrt(4990) * sum_energy_corr_median['energy']) ,fmt='-o', label = 'median')
plt.errorbar(np.sqrt(sum_energy_corr_gamma['energy']), sum_energy_corr_gamma['mean']/sum_energy_corr_gamma['energy'], yerr = sum_energy_corr_gamma['sigma']/(np.sqrt(4990) * sum_energy_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Sum Energy', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy_complete.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_corr_gauss['energy']), sum_energy_corr_gauss['sigma']/sum_energy_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['sigma']/sum_energy_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_energy_corr_gauss2s['energy']), sum_energy_corr_gauss2s['sigma']/sum_energy_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
plt.plot(1/np.sqrt(sum_energy_corr_rms68['energy']), sum_energy_corr_rms68['sigma']/sum_energy_corr_rms68['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_energy_corr_rms90['energy']), sum_energy_corr_rms90['sigma']/sum_energy_corr_rms90['mean'] , 'o-', label = 'RMS90')
plt.plot(1/np.sqrt(sum_energy_corr_median['energy']), sum_energy_corr_median['sigma']/sum_energy_corr_median['mean'] , 'o-', label = 'median')
plt.plot(1/np.sqrt(sum_energy_corr_gamma['energy']), sum_energy_corr_gamma['sigma']/sum_energy_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Sum Energy', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy_complete.png')

'''
#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_corr_gauss['energy'], sum_energy_corr_gauss['mean'], yerr = sum_energy_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_corr_mean['energy'], sum_energy_corr_mean['mean'], yerr = sum_energy_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_corr_gauss2s['energy'], sum_energy_corr_gauss2s['mean'], yerr = sum_energy_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_corr_rms68['energy'], sum_energy_corr_rms68['mean'], yerr = sum_energy_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.errorbar(sum_energy_corr_median['energy'], sum_energy_corr_median['mean'], yerr = sum_energy_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for sum energy', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy.png')
'''
# Out:
# "\n#standard linearity plot\nplt.figure(figsize=(14,7))\nplt.errorbar(sum_energy_corr_gauss['energy'], sum_energy_corr_gauss['mean'], yerr = sum_energy_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')\nplt.errorbar(sum_energy_corr_mean['energy'], sum_energy_corr_mean['mean'], yerr = sum_energy_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')\nplt.errorbar(sum_energy_corr_gauss2s['energy'], sum_energy_corr_gauss2s['mean'], yerr = sum_energy_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\\sigma$)')\nplt.errorbar(sum_energy_corr_rms68['energy'], sum_energy_corr_rms68['mean'], yerr = sum_energy_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')\nplt.errorbar(sum_energy_corr_median['energy'], sum_energy_corr_median['mean'], yerr = sum_energy_corr_median['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')\nplt.title('Linearity Plot for sum energy', fontsize=15)\nplt.xlabel('Energy Simulation [GeV]', fontsize = 15)\nplt.ylabel('(Energy Predicted) / (Energy Simu
# ...

# %%
#weighted sum of the energy
sum_energy_weighted_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_mean.txt', header=0)
sum_energy_weighted_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss.txt', header=0)
sum_energy_weighted_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_mean.txt', header=0)
sum_energy_weighted_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss2s.txt', header=0)
sum_energy_weighted_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms68.txt', header=0)
sum_energy_weighted_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms90.txt', header=0)


#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_weighted_mean['mean'], sum_energy_weighted_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('Weighted sum energy', fontsize=17)
plt.title('Weighted sum energy vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss['energy']), sum_energy_weighted_corr_gauss['mean']/sum_energy_weighted_corr_gauss['energy'], yerr = sum_energy_weighted_corr_gauss['mean_err']/sum_energy_weighted_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['mean']/sum_energy_weighted_corr_mean['energy'], yerr = sum_energy_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2s['energy']), sum_energy_weighted_corr_gauss2s['mean']/sum_energy_weighted_corr_gauss2s['energy'], yerr = sum_energy_weighted_corr_gauss2s['mean_err']/sum_energy_weighted_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms68['energy']), sum_energy_weighted_corr_rms68['mean']/sum_energy_weighted_corr_rms68['energy'], yerr = sum_energy_weighted_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_energy_weighted_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms90['energy']), sum_energy_weighted_corr_rms90['mean']/sum_energy_weighted_corr_rms90['energy'], yerr = sum_energy_weighted_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_energy_weighted_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.title('Linearity Plot for Weighted Sum Energy (1)', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.legend(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy_weighted1.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss['energy']), sum_energy_weighted_corr_gauss['sigma']/sum_energy_weighted_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['sigma']/sum_energy_weighted_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2s['energy']), sum_energy_weighted_corr_gauss2s['sigma']/sum_energy_weighted_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms68['energy']), sum_energy_weighted_corr_rms68['sigma']/sum_energy_weighted_corr_rms68['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms90['energy']), sum_energy_weighted_corr_rms90['sigma']/sum_energy_weighted_corr_rms90['mean'] , 'o-', label = 'RMS90')
plt.grid()
plt.title('Resolution Plot for Weighted Sum Energy (1)', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy_weighted1.png')



#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_weighted_corr_gauss['energy'], sum_energy_weighted_corr_gauss['mean'], yerr = sum_energy_weighted_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_weighted_corr_mean['energy'], sum_energy_weighted_corr_mean['mean'], yerr = sum_energy_weighted_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_weighted_corr_gauss2s['energy'], sum_energy_weighted_corr_gauss2s['mean'], yerr = sum_energy_weighted_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_weighted_corr_rms68['energy'], sum_energy_weighted_corr_rms68['mean'], yerr = sum_energy_weighted_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for Weighted sum energy', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.legend(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy_weighted.png')

# %%
#weighted sum of the energy
sum_energy_weighted_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_mean_test.txt', header=0)
sum_energy_weighted_corr_gauss = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss_test.txt', header=0)
sum_energy_weighted_corr_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_mean_test.txt', header=0)
sum_energy_weighted_corr_gauss2s = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss2s_test.txt', header=0)
sum_energy_weighted_corr_rms68 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms68_test.txt', header=0)
sum_energy_weighted_corr_rms90 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms90_test.txt', header=0)
sum_energy_weighted_corr_median = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_median_test.txt', header=0)
sum_energy_weighted_corr_gamma = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gamma_test.txt', header=0)


#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_weighted_mean['mean'], sum_energy_weighted_mean['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('Weighted sum energy', fontsize=17)
plt.title('Weighted sum energy vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss['energy']), sum_energy_weighted_corr_gauss['mean']/sum_energy_weighted_corr_gauss['energy'], yerr = sum_energy_weighted_corr_gauss['mean_err']/sum_energy_weighted_corr_gauss['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['mean']/sum_energy_weighted_corr_mean['energy'], yerr = sum_energy_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2s['energy']), sum_energy_weighted_corr_gauss2s['mean']/sum_energy_weighted_corr_gauss2s['energy'], yerr = sum_energy_weighted_corr_gauss2s['mean_err']/sum_energy_weighted_corr_gauss2s['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms68['energy']), sum_energy_weighted_corr_rms68['mean']/sum_energy_weighted_corr_rms68['energy'], yerr = sum_energy_weighted_corr_rms68['sigma']/(np.sqrt(4990*0.68) * sum_energy_weighted_corr_rms68['energy']) ,fmt='-o', label = 'RMS68')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms90['energy']), sum_energy_weighted_corr_rms90['mean']/sum_energy_weighted_corr_rms90['energy'], yerr = sum_energy_weighted_corr_rms90['sigma']/(np.sqrt(4990*0.9) * sum_energy_weighted_corr_rms90['energy']) ,fmt='-o', label = 'RMS90')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_median['energy']), sum_energy_weighted_corr_median['mean']/sum_energy_weighted_corr_median['energy'], yerr = sum_energy_weighted_corr_median['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_median['energy']) ,fmt='-o', label = 'median')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gamma['energy']), sum_energy_weighted_corr_gamma['mean']/sum_energy_weighted_corr_gamma['energy'], yerr = sum_energy_weighted_corr_gamma['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_gamma['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Weighted Sum Energy (Si + W)', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.legend(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy_weighted1_rms.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss['energy']), sum_energy_weighted_corr_gauss['sigma']/sum_energy_weighted_corr_gauss['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['sigma']/sum_energy_weighted_corr_mean['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2s['energy']), sum_energy_weighted_corr_gauss2s['sigma']/sum_energy_weighted_corr_gauss2s['mean'] , 'o-', label = 'gauss(2$\sigma$)')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms68['energy']), sum_energy_weighted_corr_rms68['sigma']/sum_energy_weighted_corr_rms68['mean'] , 'o-', label = 'RMS68')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms90['energy']), sum_energy_weighted_corr_rms90['sigma']/sum_energy_weighted_corr_rms90['mean'] , 'o-', label = 'RMS90')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_median['energy']), sum_energy_weighted_corr_median['sigma']/sum_energy_weighted_corr_median['mean'] , 'o-', label = 'median')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gamma['energy']), sum_energy_weighted_corr_gamma['sigma']/sum_energy_weighted_corr_gamma['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Weighted Sum Energy (Si + W)', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy_weighted1_rms.png')



#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_weighted_corr_gauss['energy'], sum_energy_weighted_corr_gauss['mean'], yerr = sum_energy_weighted_corr_gauss['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_weighted_corr_mean['energy'], sum_energy_weighted_corr_mean['mean'], yerr = sum_energy_weighted_corr_mean['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_weighted_corr_gauss2s['energy'], sum_energy_weighted_corr_gauss2s['mean'], yerr = sum_energy_weighted_corr_gauss2s['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_weighted_corr_rms68['energy'], sum_energy_weighted_corr_rms68['mean'], yerr = sum_energy_weighted_corr_rms68['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for Weighted sum energy', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.legend(fontsize=15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy_weighted.png')

# %%
#weighted sum of the energy
sum_energy_weighted_mean2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_mean2.txt', header=0)
sum_energy_weighted_corr_gauss2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss2.txt', header=0)
sum_energy_weighted_corr_mean2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_mean2.txt', header=0)
sum_energy_weighted_corr_gauss2s2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss2s2.txt', header=0)
sum_energy_weighted_corr_rms682 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms682.txt', header=0)
sum_energy_weighted_corr_rms902 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms902.txt', header=0)


#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_weighted_mean2['mean'], sum_energy_weighted_mean2['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('Weighted sum energy (2)', fontsize=17)
plt.title('Weighted sum energy (2) vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2['energy']), sum_energy_weighted_corr_gauss2['mean']/sum_energy_weighted_corr_gauss2['energy'], yerr = sum_energy_weighted_corr_gauss2['mean_err']/sum_energy_weighted_corr_gauss2['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['mean']/sum_energy_weighted_corr_mean2['energy'], yerr = sum_energy_weighted_corr_mean2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'mean')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2s2['energy']), sum_energy_weighted_corr_gauss2s2['mean']/sum_energy_weighted_corr_gauss2s2['energy'], yerr = sum_energy_weighted_corr_gauss2s2['mean_err']/sum_energy_weighted_corr_gauss2s2['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms682['energy']), sum_energy_weighted_corr_rms682['mean']/sum_energy_weighted_corr_rms682['energy'], yerr = sum_energy_weighted_corr_rms682['sigma']/(np.sqrt(4990*0.68) * sum_energy_weighted_corr_rms682['energy']) ,fmt='-o', label = 'RMS68')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms902['energy']), sum_energy_weighted_corr_rms902['mean']/sum_energy_weighted_corr_rms902['energy'], yerr = sum_energy_weighted_corr_rms902['sigma']/(np.sqrt(4990*0.9) * sum_energy_weighted_corr_rms902['energy']) ,fmt='-o', label = 'RMS90')
plt.title('Linearity Plot for Weighted Sum Energy (2)', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy_weighted2.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2['energy']), sum_energy_weighted_corr_gauss2['sigma']/sum_energy_weighted_corr_gauss2['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['sigma']/sum_energy_weighted_corr_mean2['mean'], 'o-', label = 'mean')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2s2['energy']), sum_energy_weighted_corr_gauss2s2['sigma']/sum_energy_weighted_corr_gauss2s2['mean'] , 'o-', label = 'gauss(2$\sigma$)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms682['energy']), sum_energy_weighted_corr_rms682['sigma']/sum_energy_weighted_corr_rms682['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms902['energy']), sum_energy_weighted_corr_rms902['sigma']/sum_energy_weighted_corr_rms902['mean'] , 'o-', label = 'RMS90')
plt.grid()
plt.title('Resolution Plot for Weighted Sum Energy (2)', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy_weighted2.png')



#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_weighted_corr_gauss2['energy'], sum_energy_weighted_corr_gauss2['mean'], yerr = sum_energy_weighted_corr_gauss2['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_weighted_corr_mean2['energy'], sum_energy_weighted_corr_mean2['mean'], yerr = sum_energy_weighted_corr_mean2['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_weighted_corr_gauss2s2['energy'], sum_energy_weighted_corr_gauss2s2['mean'], yerr = sum_energy_weighted_corr_gauss2s2['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_weighted_corr_rms682['energy'], sum_energy_weighted_corr_rms682['mean'], yerr = sum_energy_weighted_corr_rms682['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for Weighted sum energy (2)', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy_weighted.png')

# %%
#weighted sum of the energy
sum_energy_weighted_mean2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_mean_test2.txt', header=0)
sum_energy_weighted_corr_gauss2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss_test2.txt', header=0)
sum_energy_weighted_corr_mean2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_mean_test2.txt', header=0)
sum_energy_weighted_corr_gauss2s2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gauss2s_test2.txt', header=0)
sum_energy_weighted_corr_rms682 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms68_test2.txt', header=0)
sum_energy_weighted_corr_rms902 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_rms90_test2.txt', header=0)
sum_energy_weighted_corr_median2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_median_test2.txt', header=0)
sum_energy_weighted_corr_gamma2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_sum_energy_weighted_corr_gamma_test2.txt', header=0)


#maybe also include the fit!
plt.figure(figsize=(16,9))
plt.plot(sum_energy_weighted_mean2['mean'], sum_energy_weighted_mean2['energy'],'o-', label = 'simulation data')
plt.legend()
plt.grid()
plt.xlabel('Energy [GeV]', fontsize=17)
plt.ylabel('Weighted sum energy (2)', fontsize=17)
plt.title('Weighted sum energy (2) vs. Energy', fontsize=17)


#ratio linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2['energy']), sum_energy_weighted_corr_gauss2['mean']/sum_energy_weighted_corr_gauss2['energy'], yerr = sum_energy_weighted_corr_gauss2['mean_err']/sum_energy_weighted_corr_gauss2['energy'] ,fmt='-o', label = 'gauss')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['mean']/sum_energy_weighted_corr_mean2['energy'], yerr = sum_energy_weighted_corr_mean2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'mean')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_gauss2s2['energy']), sum_energy_weighted_corr_gauss2s2['mean']/sum_energy_weighted_corr_gauss2s2['energy'], yerr = sum_energy_weighted_corr_gauss2s2['mean_err']/sum_energy_weighted_corr_gauss2s2['energy'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms682['energy']), sum_energy_weighted_corr_rms682['mean']/sum_energy_weighted_corr_rms682['energy'], yerr = sum_energy_weighted_corr_rms682['sigma']/(np.sqrt(4990*0.68) * sum_energy_weighted_corr_rms682['energy']) ,fmt='-o', label = 'RMS68')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_rms902['energy']), sum_energy_weighted_corr_rms902['mean']/sum_energy_weighted_corr_rms902['energy'], yerr = sum_energy_weighted_corr_rms902['sigma']/(np.sqrt(4990*0.9) * sum_energy_weighted_corr_rms902['energy']) ,fmt='-o', label = 'RMS90')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_median2['energy']), sum_energy_weighted_corr_median2['mean']/sum_energy_weighted_corr_median2['energy'], yerr = sum_energy_weighted_corr_median2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_median2['energy']) ,fmt='-o', label = 'median')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_gamma2['energy']), sum_energy_weighted_corr_gamma2['mean']/sum_energy_weighted_corr_gamma2['energy'], yerr = sum_energy_weighted_corr_gamma2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_gamma2['energy']) ,fmt='-o', label = 'gamma')
plt.title('Linearity Plot for Weighted Sum Energy (W)', fontsize=15)
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.ylim(0.9,1.1)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/ratio_sum_energy_weighted2_rms.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2['energy']), sum_energy_weighted_corr_gauss2['sigma']/sum_energy_weighted_corr_gauss2['mean'], 'o-', label = 'gauss')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['sigma']/sum_energy_weighted_corr_mean2['mean'], 'o-', label = 'mean')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_gauss2s2['energy']), sum_energy_weighted_corr_gauss2s2['sigma']/sum_energy_weighted_corr_gauss2s2['mean'] , 'o-', label = 'gauss(2$\sigma$)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms682['energy']), sum_energy_weighted_corr_rms682['sigma']/sum_energy_weighted_corr_rms682['mean'] , 'o-', label = 'RMS68')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_rms902['energy']), sum_energy_weighted_corr_rms902['sigma']/sum_energy_weighted_corr_rms902['mean'] , 'o-', label = 'RMS90')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_median2['energy']), sum_energy_weighted_corr_median2['sigma']/sum_energy_weighted_corr_median2['mean'] , 'o-', label = 'median')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_gamma2['energy']), sum_energy_weighted_corr_gamma2['sigma']/sum_energy_weighted_corr_gamma2['mean'] , 'o-', label = 'gamma')
plt.grid()
plt.title('Resolution Plot for Weighted Sum Energy (W)', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(0, 44)
plt.legend(fontsize=15)
#plt.ylim(0, 0.25)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_sum_energy_weighted2_rms.png')



#standard linearity plot
plt.figure(figsize=(14,7))
plt.errorbar(sum_energy_weighted_corr_gauss2['energy'], sum_energy_weighted_corr_gauss2['mean'], yerr = sum_energy_weighted_corr_gauss2['mean_err'] ,fmt='-o', label = 'gauss')
plt.errorbar(sum_energy_weighted_corr_mean2['energy'], sum_energy_weighted_corr_mean2['mean'], yerr = sum_energy_weighted_corr_mean2['sigma']/np.sqrt(4990) ,fmt='-o', label = 'mean')
plt.errorbar(sum_energy_weighted_corr_gauss2s2['energy'], sum_energy_weighted_corr_gauss2s2['mean'], yerr = sum_energy_weighted_corr_gauss2s2['mean_err'] ,fmt='-o', label = 'gauss(2$\sigma$)')
plt.errorbar(sum_energy_weighted_corr_rms682['energy'], sum_energy_weighted_corr_rms682['mean'], yerr = sum_energy_weighted_corr_rms682['sigma']/np.sqrt(4990) ,fmt='-o', label = 'RMS68')
plt.title('Linearity Plot for Weighted Sum Energy (2)', fontsize=15)
plt.xlabel('Energy Simulation [GeV]', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.legend(fontsize=15)
plt.grid()
#plt.savefig('linearity_nenergy_weighted.png')

# %%
plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], 'o-', label = 'number of hits')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], 'o-', label = 'weighted number of hits (W)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['sigma']/sum_energy_weighted_corr_mean2['mean'], 'o-', label = 'weighted sum hit energy (W)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['sigma']/sum_energy_weighted_corr_mean['mean'] , 'o-', label = 'weighted sum hit energy (Si + W)')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['sigma']/sum_energy_corr_mean['mean'] , 'o-', label = 'sum hit energy')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , 'o-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('resolution vs. energy', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_plot_crossing.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'number of hits')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted number of hits (W)')
plt.errorbar(np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['mean']/sum_energy_corr_mean['energy'], yerr = sum_energy_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_corr_mean['energy']) ,fmt='-o', label = 'sum hit energy')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['mean']/sum_energy_weighted_corr_mean['energy'], yerr = sum_energy_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted sum hit energy (Si + W)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['mean']/sum_energy_weighted_corr_mean2['energy'], yerr = sum_energy_weighted_corr_mean2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'weighted sum hit energy (W)')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , 'o-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('linearity plot', fontsize = 15)
plt.xlabel('$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/linearity_plot.png')
# Out:
# Text(0, 0.5, '(Energy Predicted) / (Energy Simulation)')

# %%
#likelihood_mean = np.array([0.24156080753793996, 0.48584717219364887, 0.683119063220611, 0.9825296768409313, 1.9808133317202758, 4.973945461508703, 7.977076348770743, 9.979083163159546, 19.967102259454073, 39.95514798923491, 59.953412973485214, 79.96137808935647, 99.93978098201134, 149.92988934901703, 199.91127045216354, 249.7941552309734])
#likelihood_std = np.array([0.09035496931786789, 0.13852551739555088, 0.16993319660131512, 0.20691307295608127, 0.3004460217182542, 0.5116534077805852, 0.6606838370751252, 0.7324090747538701, 1.0918442500244636, 1.6163024171060911, 2.1849469372265524, 2.4557109936223895, 2.867636840051163, 3.6027806788638985, 4.371981982605625, 5.980064575928151])
#likelihood_gauss = np.array([0.21574308672847345, 0.4665982000214665, 0.6624497842188328, 0.9597463442109815, 1.95145522946781, 4.9416582758066125, 7.9508547395486415, 9.949684207892561, 19.91897337271764, 39.92863929031698, 59.98896687113191, 79.99807101067087, 99.96873214005427, 150.11691027248875, 200.11769487639037, 250.57543070827626])
#likelihood_sigma = np.array([0.0841473638191423, 0.1272034891087095, 0.16265678320749613, 0.19886238856924, 0.2987523213273501, 0.5042668438453142, 0.6512670115115312, 0.7382621529605, 1.0723599478919192, 1.586173217402831, 1.9954484427352486, 2.3182774506524857, 2.67077626941439, 3.356249292670378, 3.7142211462214254, 5.279634517084388])

likelihood_mean = np.array([0.24160146754390813, 0.485777686911541, 0.6830648663572686, 0.9823888398150346, 1.9807854503633753, 4.97397563619522, 7.977107423954878, 9.97910680255808, 19.967128826805915, 39.95517251977871, 59.953371936045166, 79.96133599443294, 99.93979377468894, 149.9299410508072, 199.91120534164392, 249.842845121093])
likelihood_std = np.array([0.09033984488023487, 0.13864948865107998, 0.16988691942092465, 0.2069704001978659, 0.30042422877281877, 0.5116367639472055, 0.6606429259754398, 0.7322910100858773, 1.0918958800886753, 1.6162216057428462, 2.184995083364849, 2.455652594216624, 2.867591503956478, 3.602756668063604, 4.371907886957594, 6.068431650352547])
likelihood_gauss = np.array([0.21259366355326198, 0.4656342786315913, 0.6613784039683926, 0.9601747897164145, 1.9511981624545154, 4.940333577198562, 7.951710502672478, 9.94871609061739, 19.917739782235405, 39.92640283495587, 59.98515280649829, 79.99702075980859, 99.96957653118614, 150.11402237772697, 200.11797715276103, 250.3815796087705])
likelihood_sigma = np.array([0.0836467717294321, 0.1329543620297871, 0.1604890533877527, 0.19889895300368868, 0.297902291821654, 0.5064689688719081, 0.6513302034604966, 0.7358694377851591, 1.0719362700914192, 1.5881463092727552, 1.9981503394166984, 2.3176695561818064, 2.6661010766189968, 3.3560127481393773, 3.7168648530287096, 4.963948141284052])
likelihood_rand_mean = np.array([0.31589602980149, 0.4928303565178258, 0.6785531626581329, 0.9923574678733936, 1.9681831041552078, 4.966973758687935, 7.980336876843841, 10.037542552127606, 19.9381219860993, 39.932177388869434, 59.96572800640031, 79.92797811390568, 99.88149268463421, 149.88486993349667, 199.7880929296465, 249.5325144557228])
likelihood_rand_std = np.array([0.043775035986355286, 0.1366156510349929, 0.16650746540330086, 0.20653566365732404, 0.2993412894797135, 0.510686782361554, 0.6575630527377815, 0.7423278434091994, 1.1014111455275801, 1.5833730358827929, 2.0198357844993278, 2.4628037445951345, 2.8146205040347394, 3.484279361433691, 4.608742136812576, 6.686732218890431])
linear_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_linear_mean.txt')
print(linear_mean)
plt.figure(figsize=(14,7), facecolor='white')
plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], '-', label = 'number of hits')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], '-', label = 'weighted number of hits (W)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['sigma']/sum_energy_weighted_corr_mean2['mean'], '-', label = 'weighted sum hit energy (W)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['sigma']/sum_energy_weighted_corr_mean['mean'] , '-', label = 'weighted sum hit energy (Si + W)')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['sigma']/sum_energy_corr_mean['mean'] , '-', label = 'sum hit energy')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_std/likelihood_mean , '-', label = 'likelihood mean')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_sigma/likelihood_gauss , '-', label = 'likelihood gaussian')
plt.plot(1/np.sqrt(linear_mean['energy']), linear_mean['sigma']/linear_mean['mean'] , '-', label = 'linear combination')
#plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_rand_std/likelihood_rand_mean , '-', label = 'likelihood random')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , '-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('resolution vs. energy', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_likelihood.png')


plt.figure(figsize=(14,7), facecolor='white')
plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'number of hits')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted number of hits (W)')
plt.errorbar(np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['mean']/sum_energy_corr_mean['energy'], yerr = sum_energy_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_corr_mean['energy']) ,fmt='-o', label = 'sum hit energy')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['mean']/sum_energy_weighted_corr_mean['energy'], yerr = sum_energy_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted sum hit energy (Si + W)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['mean']/sum_energy_weighted_corr_mean2['energy'], yerr = sum_energy_weighted_corr_mean2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'weighted sum hit energy (W)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_mean/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_std/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood mean')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_gauss/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_sigma/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood gauss')
plt.errorbar(np.sqrt(linear_mean['energy']), linear_mean['mean']/linear_mean['energy'], yerr = linear_mean['sigma']/(np.sqrt(4990) * linear_mean['energy']) ,fmt='-o', label = 'linear combination')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_rand_mean/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_rand_std/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood random')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , '-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(8,16)
plt.ylim(0.96,1.025)
plt.title('linearity plot', fontsize = 15)
plt.xlabel('$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/linearity_likelihood_zoom.png')
# Out:
#     energy        mean     sigma
# 0     0.25    0.252498  0.088655
# 1     0.50    0.502228  0.137169
# 2     0.70    0.701754  0.166434
# 3     1.00    1.001430  0.203533
# 4     2.00    2.003650  0.297298
# 5     5.00    5.004340  0.513955
# 6     8.00    8.004780  0.669378
# 7    10.00   10.005700  0.746065
# 8    20.00   20.006100  1.138560
# 9    40.00   40.012600  1.751110
# 10   60.00   60.029100  2.363980
# 11   80.00   80.022200  2.788820
# 12  100.00  100.042000  3.264370
# 13  150.00  150.043000  4.342720
# 14  200.00  200.076000  5.484210
# 15  250.00  250.203000  7.630240
# Text(0, 0.5, '(Energy Predicted) / (Energy Simulation)')

# %%
#likelihood_mean = np.array([0.24156080753793996, 0.48584717219364887, 0.683119063220611, 0.9825296768409313, 1.9808133317202758, 4.973945461508703, 7.977076348770743, 9.979083163159546, 19.967102259454073, 39.95514798923491, 59.953412973485214, 79.96137808935647, 99.93978098201134, 149.92988934901703, 199.91127045216354, 249.7941552309734])
#likelihood_std = np.array([0.09035496931786789, 0.13852551739555088, 0.16993319660131512, 0.20691307295608127, 0.3004460217182542, 0.5116534077805852, 0.6606838370751252, 0.7324090747538701, 1.0918442500244636, 1.6163024171060911, 2.1849469372265524, 2.4557109936223895, 2.867636840051163, 3.6027806788638985, 4.371981982605625, 5.980064575928151])
#likelihood_gauss = np.array([0.21574308672847345, 0.4665982000214665, 0.6624497842188328, 0.9597463442109815, 1.95145522946781, 4.9416582758066125, 7.9508547395486415, 9.949684207892561, 19.91897337271764, 39.92863929031698, 59.98896687113191, 79.99807101067087, 99.96873214005427, 150.11691027248875, 200.11769487639037, 250.57543070827626])
#likelihood_sigma = np.array([0.0841473638191423, 0.1272034891087095, 0.16265678320749613, 0.19886238856924, 0.2987523213273501, 0.5042668438453142, 0.6512670115115312, 0.7382621529605, 1.0723599478919192, 1.586173217402831, 1.9954484427352486, 2.3182774506524857, 2.67077626941439, 3.356249292670378, 3.7142211462214254, 5.279634517084388])

likelihood_mean = np.array([0.24160146754390813, 0.485777686911541, 0.6830648663572686, 0.9823888398150346, 1.9807854503633753, 4.97397563619522, 7.977107423954878, 9.97910680255808, 19.967128826805915, 39.95517251977871, 59.953371936045166, 79.96133599443294, 99.93979377468894, 149.9299410508072, 199.91120534164392, 249.842845121093])
likelihood_std = np.array([0.09033984488023487, 0.13864948865107998, 0.16988691942092465, 0.2069704001978659, 0.30042422877281877, 0.5116367639472055, 0.6606429259754398, 0.7322910100858773, 1.0918958800886753, 1.6162216057428462, 2.184995083364849, 2.455652594216624, 2.867591503956478, 3.602756668063604, 4.371907886957594, 6.068431650352547])
likelihood_gauss = np.array([0.21259366355326198, 0.4656342786315913, 0.6613784039683926, 0.9601747897164145, 1.9511981624545154, 4.940333577198562, 7.951710502672478, 9.94871609061739, 19.917739782235405, 39.92640283495587, 59.98515280649829, 79.99702075980859, 99.96957653118614, 150.11402237772697, 200.11797715276103, 250.3815796087705])
likelihood_sigma = np.array([0.0836467717294321, 0.1329543620297871, 0.1604890533877527, 0.19889895300368868, 0.297902291821654, 0.5064689688719081, 0.6513302034604966, 0.7358694377851591, 1.0719362700914192, 1.5881463092727552, 1.9981503394166984, 2.3176695561818064, 2.6661010766189968, 3.3560127481393773, 3.7168648530287096, 4.963948141284052])
likelihood_rand_mean = np.array([0.31589602980149, 0.4928303565178258, 0.6785531626581329, 0.9923574678733936, 1.9681831041552078, 4.966973758687935, 7.980336876843841, 10.037542552127606, 19.9381219860993, 39.932177388869434, 59.96572800640031, 79.92797811390568, 99.88149268463421, 149.88486993349667, 199.7880929296465, 249.5325144557228])
likelihood_rand_std = np.array([0.043775035986355286, 0.1366156510349929, 0.16650746540330086, 0.20653566365732404, 0.2993412894797135, 0.510686782361554, 0.6575630527377815, 0.7423278434091994, 1.1014111455275801, 1.5833730358827929, 2.0198357844993278, 2.4628037445951345, 2.8146205040347394, 3.484279361433691, 4.608742136812576, 6.686732218890431])
linear_mean = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_params_linear_mean.txt')
#print(linear_mean)

plt.figure(figsize=(14,7), facecolor='white')
#plt.plot(1/np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['sigma']/sum_hits_corr_mean['mean'], '-o', label = 'number of hits')
plt.plot(1/np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['sigma']/sum_hits_weighted_corr_mean['mean'], '-o', label = 'weighted number of hits (W)')
plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['sigma']/sum_energy_weighted_corr_mean2['mean'], '-o', label = 'weighted sum hit energy (W)')
#plt.plot(1/np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['sigma']/sum_energy_weighted_corr_mean['mean'] , '-o', label = 'weighted sum hit energy (Si + W)')
#plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['sigma']/sum_energy_corr_mean['mean'] , '-o', label = 'sum hit energy')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_std/likelihood_mean , '-o', label = 'likelihood mean')
plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_sigma/likelihood_gauss , '-o', label = 'likelihood gaussian')
plt.plot(1/np.sqrt(linear_mean['energy']), linear_mean['sigma']/linear_mean['mean'] , '-o', label = 'linear combination')
#plt.plot(1/np.sqrt(sum_energy_corr_mean['energy']), likelihood_rand_std/likelihood_rand_mean , '-', label = 'likelihood random')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , '-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.title('resolution vs. energy', fontsize = 15)
plt.xlabel('1/$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('$\sigma$/$\mu$', fontsize = 15)
#plt.ylim(0,0.3)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/resolution_likelihood.png')


plt.figure(figsize=(14,7), facecolor='white')
#plt.errorbar(np.sqrt(sum_hits_corr_mean['energy']), sum_hits_corr_mean['mean']/sum_hits_corr_mean['energy'], yerr = sum_hits_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_corr_mean['energy']) ,fmt='-o', label = 'number of hits')
plt.errorbar(np.sqrt(sum_hits_weighted_corr_mean['energy']), sum_hits_weighted_corr_mean['mean']/sum_hits_weighted_corr_mean['energy'], yerr = sum_hits_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_hits_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted number of hits (W)')
#plt.errorbar(np.sqrt(sum_energy_corr_mean['energy']), sum_energy_corr_mean['mean']/sum_energy_corr_mean['energy'], yerr = sum_energy_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_corr_mean['energy']) ,fmt='-o', label = 'sum hit energy')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean['energy']), sum_energy_weighted_corr_mean['mean']/sum_energy_weighted_corr_mean['energy'], yerr = sum_energy_weighted_corr_mean['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean['energy']) ,fmt='-o', label = 'weighted sum hit energy (Si + W)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), sum_energy_weighted_corr_mean2['mean']/sum_energy_weighted_corr_mean2['energy'], yerr = sum_energy_weighted_corr_mean2['sigma']/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'weighted sum hit energy (W)')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_mean/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_std/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood mean')
plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_gauss/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_sigma/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood gauss')
plt.errorbar(np.sqrt(linear_mean['energy']), linear_mean['mean']/linear_mean['energy'], yerr = linear_mean['sigma']/(np.sqrt(4990) * linear_mean['energy']) ,fmt='-o', label = 'linear combination')
#plt.errorbar(np.sqrt(sum_energy_weighted_corr_mean2['energy']), likelihood_rand_mean/sum_energy_weighted_corr_mean2['energy'], yerr = likelihood_rand_std/(np.sqrt(4990) * sum_energy_weighted_corr_mean2['energy']) ,fmt='-o', label = 'likelihood random')
#plt.plot(1/np.sqrt(sum_hits_corr_rms68['energy']), sum_hits_corr_rms68['sigma']/sum_hits_corr_rms68['mean'] , '-', label = 'RMS68')
plt.grid()
plt.legend(fontsize = 15)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
#plt.xlim(8,16)
plt.ylim(0.975,1.025)
plt.title('linearity plot', fontsize = 15)
plt.xlabel('$\sqrt{E [GeV]}$', fontsize = 15)
plt.ylabel('(Energy Predicted) / (Energy Simulation)', fontsize = 15)
#plt.savefig('/home/llr/ilc/ritzmann/work/plots/linearity_likelihood_zoom.png')
# Out:
# Text(0, 0.5, '(Energy Predicted) / (Energy Simulation)')

# %%
ratio_hits = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_hits.txt', header=0)
ratio_sumE = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy.txt',header=0)
ratio_wsumE = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy_weighted1.txt',header=0)
ratio_wsumE2 = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy_weighted2.txt',header=0)

plt.figure(figsize=(14,7))
plt.plot(np.sqrt(ratio_hits['energy']), ratio_hits['ratio'], '-o', label = 'nhits')
plt.plot(np.sqrt(ratio_sumE['energy']), ratio_sumE['ratio'], 'o-', label = 'sumE')
plt.plot(np.sqrt(ratio_wsumE['energy']), ratio_wsumE['ratio'], '-o', label = 'wsumE')
plt.plot(np.sqrt(ratio_wsumE2['energy']), ratio_wsumE2['ratio'], '-o', label = 'wsumE2')
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('entries outside of $\pm 3 \sigma$ / total entries', fontsize=15)
plt.legend(fontsize=15)
plt.grid()

# %%
ratio_hits_fit = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_hits_fitted.txt', header=0)
ratio_sumE_fit = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy_fitted.txt',header=0)
ratio_wsumE_fit = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy_weighted1_fitted.txt',header=0)
ratio_wsumE2_fit = pd.read_csv('/home/llr/ilc/ritzmann/work/res_csv_files/conf6_e-_GeV_5kevt_-42_-42_build_masked_ratio_3sigmas_sum_energy_weighted2_fitted.txt',header=0)

plt.figure(figsize=(14,7))
#plt.plot(np.sqrt(ratio_hits['energy']), ratio_hits['ratio'], '-o', label = 'nhits')
plt.plot(np.sqrt(ratio_hits_fit['energy']), ratio_hits_fit['ratio'], '-o', label = 'nhits fitted values')
#plt.plot(np.sqrt(ratio_sumE['energy']), ratio_sumE['ratio'], 'o-', label = 'sumE')
plt.plot(np.sqrt(ratio_sumE_fit['energy']), ratio_sumE_fit['ratio'], 'o-', label = 'sumE fitted values')
#plt.plot(np.sqrt(ratio_wsumE['energy']), ratio_wsumE['ratio'], '-o', label = 'wsumE')
plt.plot(np.sqrt(ratio_wsumE_fit['energy']), ratio_wsumE_fit['ratio'], '-o', label = 'wsumE fitted values')
#plt.plot(np.sqrt(ratio_wsumE2['energy']), ratio_wsumE2['ratio'], '-o', label = 'wsumE2')
plt.plot(np.sqrt(ratio_wsumE2_fit['energy']), ratio_wsumE2_fit['ratio'], '-o', label = 'wsumE2 fitted values')
plt.xlabel('$\sqrt{\mathrm{Energy\;[GeV]}}$', fontsize = 15)
plt.ylabel('entries outside of $\pm 3 \sigma$ / total entries', fontsize=15)
plt.legend(fontsize=15)
plt.grid()

# %%
name = "TB2022-06/macros/e-_3.0GeV.mac"
print(name[:-4])
# Out:
# TB2022-06/macros/e-_3.0GeV
