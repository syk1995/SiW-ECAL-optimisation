# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

ax.text(0.1, 0.5, "Input Features (X)", fontsize=12, ha="center", va="center",
        bbox=dict(boxstyle="round,pad=0.5", edgecolor="black", facecolor="lightblue"))
ax.text(0.5, 0.7, "Tree 1\n(fit residuals)", fontsize=11, ha="center", va="center",
        bbox=dict(boxstyle="round,pad=0.5", edgecolor="black", facecolor="lightgreen"))
ax.text(0.5, 0.5, "Tree 2\n(fit residuals)", fontsize=11, ha="center", va="center",
        bbox=dict(boxstyle="round,pad=0.5", edgecolor="black", facecolor="lightgreen"))
ax.text(0.5, 0.3, "Tree k\n(fit residuals)", fontsize=11, ha="center", va="center",
        bbox=dict(boxstyle="round,pad=0.5", edgecolor="black", facecolor="lightgreen"))

ax.text(0.9, 0.5, "Final Prediction (Y)", fontsize=12, ha="center", va="center",
        bbox=dict(boxstyle="round,pad=0.5", edgecolor="black", facecolor="lightcoral"))

arrowprops = dict(arrowstyle="->", color="black")
ax.annotate("", xy=(0.35, 0.7), xytext=(0.2, 0.5), arrowprops=arrowprops)
ax.annotate("", xy=(0.35, 0.5), xytext=(0.2, 0.5), arrowprops=arrowprops)
ax.annotate("", xy=(0.35, 0.3), xytext=(0.2, 0.5), arrowprops=arrowprops)

ax.annotate("", xy=(0.75, 0.5), xytext=(0.65, 0.7), arrowprops=arrowprops)
ax.annotate("", xy=(0.75, 0.5), xytext=(0.65, 0.5), arrowprops=arrowprops)
ax.annotate("", xy=(0.75, 0.5), xytext=(0.65, 0.3), arrowprops=arrowprops)

ax.axis("off")
plt.show()
